# %%
from lmptools import Dump, DumpCallback, DumpFileIterator
from lmptools.exceptions import SkipSnapshot

# %%
class MyCallback(DumpCallback):
    def on_snapshot_parse_time(self, timestamp: int):
        if timestamp < 6000:
            raise SkipSnapshot(f"snap {timestamp} skipped")

# %%
d = Dump("dump.test.lammpstrj")

# %%
d.parse(callback = MyCallback())
# Out:
# 2021-09-06 17:58:17.049 | ERROR    | lmptools.dump:__next__:277 - 'MyCallback' object has no attribute 'on_snapshot_parse_natoms'
# Traceback (most recent call last):
#
#   File "/usr/local/tools/anaconda3/2021.05/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f42f0341500, file "/home/vbala/.cache/pypoetry/virtualenvs/lmptools-JZNjlOcm-py3.8/lib/python3.8/...
#            └ <function _run_code at 0x7f42f0356ca0>
#   File "/usr/local/tools/anaconda3/2021.05/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
# ...

# %%
for snapshot in DumpFileIterator("dump.test.lammpstrj"):
    print(snapshot)
# Out:
# 2021-09-06 17:58:28.913 | ERROR    | lmptools.dump:__next__:277 - 'natoms'
# Traceback (most recent call last):
#
#   File "/usr/local/tools/anaconda3/2021.05/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f42f0341500, file "/home/vbala/.cache/pypoetry/virtualenvs/lmptools-JZNjlOcm-py3.8/lib/python3.8/...
#            └ <function _run_code at 0x7f42f0356ca0>
#   File "/usr/local/tools/anaconda3/2021.05/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
# ...
